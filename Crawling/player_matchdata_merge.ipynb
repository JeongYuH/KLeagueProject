# %%
# !pip install pandas
# !pip install openpyxl
# Out:
# ...
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#                                               0.0/250.0 kB ? eta -:--:--
#      ------------------------------------- 250.0/250.0 kB 16.0 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
player_data = pd.read_excel('2020시즌 선수단 명단.xlsx')
match_data = pd.read_excel('league_2020_1.xlsx')

# %%
player_data
# Out:
#      소속  등번호  선수명      키     체중       생년월일
# 0    강원    1  이광연  184cm   82kg 1999-09-11
# 1    강원    2  김영빈  181cm   74kg 1991-09-20
# 2    강원    3  신세계  178cm   73kg 1990-09-16
# 3    강원    4  이호인  183cm   70kg 1995-12-29
# 4    강원    6  조지훈  191cm   80kg 1990-05-29
# ..   ..  ...  ...    ...    ...        ...
# 769  제주   37  이동률  177cm   66kg 2000-06-09
# 770  제주   38  이규혁  175cm   72kg 1999-05-04
# 771  제주   39  이찬동  185cm   82kg 1993-01-10
# 772  제주   40  김재봉  188cm   78kg 1996-09-06
# 773  제주   41  김경민  189cm   81kg 1991-11-01
#
# [774 rows x 6 columns]

# %%
match_data
# Out:
#        Unnamed: 0  시즌(년도)    소속  라운드    상대팀  No.   선수명 포지션  등번호 출전시간(분)  ...  \
# 0               0    2020    울산   1R  상주(H)    1   조현우  GK   21      95  ...
# 1               1    2020    울산   1R  상주(H)    2  불투이스  DF    4      95  ...
# 2               2    2020    울산   1R  상주(H)    3  데이비슨  DF    3      95  ...
# 3               3    2020    울산   1R  상주(H)    4   정승현  DF   15      95  ...
# 4               4    2020    울산   1R  상주(H)    5   김태환  DF   23      95  ...
# ...           ...     ...   ...  ...    ...  ...   ...  ..  ...     ...  ...
# 10845       10845    2020  충남아산  27R  제주(H)   14   김민식  대기    3       -  ...
# 10846       10846    2020  충남아산  27R  제주(H)   15  헬퀴스트  대기    7       -  ...
# 10847       10847    2020  충남아산  27R  제주(H)   16   김재성  대기   19       -  ...
# 10848       10848    2020  충남아산  27R  제주(H)   17    심민  대기   21       -  ...
# 10849       10849    2020  충남아산  27R  제주(H)   18    김찬  대기    9      28  ...
#
# ...

# %%
match_player_data = pd.merge(left=match_data, right=player_data, how='outer', on=['선수명', '소속', '등번호'])

# %%
match_player_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10967 entries, 0 to 10966
# Data columns (total 82 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  10850 non-null  float64
#  1   시즌(년도)      10850 non-null  float64
#  2   소속          10967 non-null  object
#  3   라운드         10850 non-null  object
#  4   상대팀         10850 non-null  object
#  5   No.         10850 non-null  float64
#  6   선수명         10967 non-null  object
#  7   포지션         10850 non-null  object
#  8   등번호         10967 non-null  int64
#  9   출전시간(분)     10850 non-null  object
#  10  득점          10850 non-null  float64
#  11  도움          10850 non-null  float64
#  12  슈팅          10850 non-null  float64
#  13  유효슈팅        10850 non-null  float64
#  14  블락된슈팅       10850 non-null  float64
#  15  벗어난슈팅       10850 non-null  float64
#  16  PA내슈팅       10850 non-null  float64
#  17  PA외슈팅       10850 non-null  float64
# ...

# %%
match_player_data1 = match_player_data.drop(columns=['Unnamed: 0'])

# %%
match_player_data1.to_excel('2020_match_data.xlsx')
